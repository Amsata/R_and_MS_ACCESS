# %% [markdown]
# # Comment connecter R et Microsoft ACCESS
#
# 1. Commencer par télécharger AccessDatabaseEngine ([Lien](https://www.microsoft.com/en-us/download/details.aspx?id=13255))
#
# 2. Intaller les packages `odbc` et `RODBC`

# %%
#install.packages(odcb)
#install.packages(RODBC)

# %%
library(RODBC)
library(RODBCDBI)
library(odbc)
library(dplyr)

# %%
unique(odbc::odbcListDrivers()[[1]])
# Out:
# [1] "SQL Server"
# [2] "Microsoft Access Driver (*.mdb, *.accdb)"
# [3] "Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)"
# [4] "Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)"
# [5] "Microsoft Access Text Driver (*.txt, *.csv)"

# %%
access_database="C:/Users/USER/Documents/AgriSurveyTeam/Georgia/Agriculture Holdings Surveys/1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb"

con=RODBC::odbcConnectAccess2007(access_database)
sqlTables(con)
#odbcClose(con)
# Out:
#     TABLE_CAT
# 1   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# 2   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# 3   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# 4   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# 5   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# 6   C:\\Users\\USER\\Documents\\AgriSurveyTeam\\Georgia\\Agriculture Holdings Surveys\\1_sasoplo_meurneobata_gamokvlevis_monacemta_baza_GEO.accdb
# ...

# %%
table="1_main"
main=sqlFetch(con,table)

head(main)
# Out:
#   DocID Year Quarter Code      LegalStatusID GenderID Age ParcelQty OwnedArea
# 1 49750 2020 0       100000090 100           1        53  1         200.00
# 2 49836 2020 0       100003998 100           1        73  3           1.25
# 3 49840 2020 0       100003960 100           1        92  2           1.25
# 4 50113 2020 0       100000215 100           2        47  3         120.00
# 5 50126 2020 0       100003957 100           2        85  5           1.24
# 6 50135 2020 0       100004930 100           1        59  2          10.80
#   LeasedArea LeasedAreaGov LeasedAreaPriv TotalArea HasLoan
# 1  NA         NA            NA            200.00    NA
# 2 3.5         NA           3.5              4.75    NA
# 3  NA         NA            NA              1.25    NA
# 4  NA         NA            NA            120.00    NA
# 5 2.5        2.5            NA              3.74    NA
# 6 0.0         NA            NA             10.80    NA
